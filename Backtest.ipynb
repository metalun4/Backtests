# %%
from Macd import Macd
from Tilson import Tilson
from Wtlb import Wtlb
from Multi import Multi

# %%
x = Multi(1000, 0, "BTC-USD", "6mo", "1d", 7, 0.618, 10, 21)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
x.plot_strat()

# %%
x.portfolio.tail()
# Out:
# Date
# 2022-01-15    1401.052429
# 2022-01-16    1398.991300
# 2022-01-17    1370.977385
# 2022-01-18    1375.036140
# 2022-01-19    1361.995674
# dtype: float64

# %%
x.wtlb.plot_strat()

# %%
x.wtlb.portfolio.tail()
# Out:
# Date
# 2022-01-15    1448.548825
# 2022-01-16    1446.417823
# 2022-01-17    1417.454222
# 2022-01-18    1421.650571
# 2022-01-19    1408.168026
# dtype: float64

# %%
x.tilson.plot_strat()

# %%
x.tilson.portfolio.tail()
# Out:
# Date
# 2022-01-15    1166.382398
# 2022-01-16    1166.382398
# 2022-01-17    1166.382398
# 2022-01-18    1169.835454
# 2022-01-19    1158.741054
# dtype: float64
